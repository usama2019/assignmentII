# %%
eng=int(input("enter english subject marks: "))
urd=int(input("enter urdu subject marks: "))
sci=int(input("enter science subject marks: "))
soc=int(input("enter social subject marks: "))
isl=int(input("enter islamiyat subject marks: "))
total=500

percentage=((int(eng+urd+sci+soc+isl)/total)*100)

if percentage > 100:
    print("enter valid")
elif percentage < 100 and percentage >= 80:
    print("***************")
    print('your percentage is: ',percentage,' GRADE: A+')
    print("Congradulations")
    print("***************")
    print("english        : ", eng)
    print("urdu           : ", urd)
    print("science        : ", sci)
    print("social science : ", soc)
    print("islamiyat      : ", isl)
elif percentage < 80 and percentage >= 65:
    print("***************")
    print('your percentage is: ',percentage,' GRADE: B')
    print("you can achieve more")
    print("***************")
    print("english        : ", eng)
    print("urdu           : ", urd)
    print("science        : ", sci)
    print("social science : ", soc)
    print("islamiyat      : ", isl)
elif percentage < 65 and percentage >= 55:
    print("***************")
    print('your percentage is: ',percentage,' GRADE: C')
    print("you have done better")
    print("***************")
    print("english        : ", eng)
    print("urdu           : ", urd)
    print("science        : ", sci)
    print("social science : ", soc)
    print("islamiyat      : ", isl)
elif percentage < 55 and percentage >= 35:
    print("***************")
    print('your percentage is: ',percentage,' GRADE: D')
    print("work harder")
    print("***************")
    print("english        : ", eng)
    print("urdu           : ", urd)
    print("science        : ", sci)
    print("social science : ", soc)
    print("islamiyat      : ", isl)
elif percentage < 35 and percentage >=0:
    print("***************")
    print('your percentage is: ',percentage,' GRADE: FAil')
    print("sorry better luck next time")
    print("***************")
    print("english        : ", eng)
    print("urdu           : ", urd)
    print("science        : ", sci)
    print("social science : ", soc)
    print("islamiyat      : ", isl)
else:
    print("***************")
    print('your marks are in negative')
    print("***************")
    print("english        : ",eng)
    print("urdu           : ",urd)
    print("science        : ",sci)
    print("social science : ",soc)
    print("islamiyat      : ",isl)
# Out:
# enter english subject marks: 88
# enter urdu subject marks: 67
# enter science subject marks: 34
# enter social subject marks: 56
# enter islamiyat subject marks: 3
# ***************
# your percentage is:  49.6  GRADE: D
# work harder
# ***************
# english        :  88
# urdu           :  67
# science        :  34
# social science :  56
# islamiyat      :  3
